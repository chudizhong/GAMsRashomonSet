# %% [markdown]
# Once we have the GAM Rashomon set, we can use it for various applications. We show examples for 5 different applications in this notebook.
# - Application 1: get different GAM models from the Rashomon set.
# - Application 2: get variable importance range.
# - Application 3: find the model that satisfies the monotonic constraints.
# - Application 4: find the users' preferred shape functions.
# - Application 5: explore sudden changes or abnormal patterns in the shape function.

# %%
import numpy as np
import pandas as pd
import pickle
from src.run_app import *
from matplotlib import pyplot as plt

# %% [markdown]
# Specify the filepath which stores the Rashomon set of a sparse GAM model.

# %%
dname = "diabetes"
l0 = 0.001
l2 = 0.001
m = 1.01
filepath = "{}_{}_{}_{}.p".format(dname, l0, l2, m)
filepath
# Out:
# 'diabetes_0.001_0.001_1.01.p'

# %% [markdown]
# ## Application 1: get different models from the Rashomon set.

# %%
w_samples = get_models_from_rset(filepath, n_samples=100, plot_shape=True)

# %% [markdown]
# ## Application 2: get variable importance range.

# %%
variable_importance_range(filepath, mip=False, plot_shape=True, plot_vir=True)
# Out:
# Pregnancies
# ----------------------variable importance Minus----------------------
# Second solve time: 0.000809255
# log obj: 0.3758141230607755 rset_bound: 0.37657937589518325
# Second solve time: 0.001254238
# log obj: 0.37570944055449823 rset_bound: 0.37657937589518325
# ----------------------variable importance plus LP--------------------
# log obj: 0.3765548630458194 rset_bound: 0.37657937589518325
# log obj: 0.3765311168702796 rset_bound: 0.37657937589518325
# log obj: 0.37655866781607455 rset_bound: 0.37657937589518325
# log obj: 0.3764923218060058 rset_bound: 0.37657937589518325
# time: 0.14873766899108887
# log obj: 0.3766589318916238 rset_bound: 0.37657937589518325
# log obj: 0.37660491443985705 rset_bound: 0.37657937589518325
# log obj: 0.3767069286542586 rset_bound: 0.37657937589518325
# log obj: 0.3766629558714309 rset_bound: 0.37657937589518325
# time: 0.07926058769226074
# /usr/project/xtmp/cz131/RsetGAM-camera-ready/src/rset_app.py:120: UserWarning: solution is out of the Rset.
#   warnings.warn("solution is out of the Rset. ")
# Glucose
# ----------------------variable importance Minus----------------------
# Second solve time: 0.001788382
# log obj: 0.37653265660154067 rset_bound: 0.37657937589518325
# Second solve time: 0.001306321
# log obj: 0.37660834928765496 rset_bound: 0.37657937589518325
# ----------------------variable importance plus LP--------------------
# /usr/project/xtmp/cz131/RsetGAM-camera-ready/src/rset_app.py:120: UserWarning: solution is out of the Rset.
#   warnings.warn("solution is out of the Rset. ")
# /usr/project/xtmp/cz131/RsetGAM-camera-ready/src/rset_app.py:353: UserWarning: solution is None
#   warnings.warn("solution is None")
# log obj: 0.37649230539323797 rset_bound: 0.37657937589518325
# log obj: 0.3765910148169084 rset_bound: 0.37657937589518325
# log obj: 0.37653368162489365 rset_bound: 0.37657937589518325
# log obj: 0.37653069710668907 rset_bound: 0.37657937589518325
# time: 1.2321436405181885
# log obj: 0.3764804809681555 rset_bound: 0.37657937589518325
# log obj: 0.37659115732412435 rset_bound: 0.37657937589518325
# log obj: 0.3766436021939235 rset_bound: 0.37657937589518325
# log obj: 0.37668779788737117 rset_bound: 0.37657937589518325
# log obj: 0.3765260794231445 rset_bound: 0.37657937589518325
# log obj: 0.37648783630149957 rset_bound: 0.37657937589518325
# log obj: 0.37638826409192544 rset_bound: 0.37657937589518325
# time: 0.660879373550415
# BloodPressure
# ----------------------variable importance Minus----------------------
# Second solve time: 0.002266892
# log obj: 0.3764500057380673 rset_bound: 0.37657937589518325
# Second solve time: 0.001542109
# log obj: 0.3766092588747061 rset_bound: 0.37657937589518325
# ----------------------variable importance plus LP--------------------
# /usr/project/xtmp/cz131/RsetGAM-camera-ready/src/rset_app.py:120: UserWarning: solution is out of the Rset.
#   warnings.warn("solution is out of the Rset. ")
# /usr/project/xtmp/cz131/RsetGAM-camera-ready/src/rset_app.py:353: UserWarning: solution is None
#   warnings.warn("solution is None")
# log obj: 0.37661805140991494 rset_bound: 0.37657937589518325
# log obj: 0.37656342612586235 rset_bound: 0.37657937589518325
# log obj: 0.3765916042297831 rset_bound: 0.37657937589518325
# log obj: 0.37653035140032515 rset_bound: 0.37657937589518325
# log obj: 0.3765313189864089 rset_bound: 0.37657937589518325
# log obj: 0.37647805954437136 rset_bound: 0.37657937589518325
# time: 1.2457740306854248
# log obj: 0.3761839486203263 rset_bound: 0.37657937589518325
# log obj: 0.3762115107735552 rset_bound: 0.37657937589518325
# log obj: 0.37673164717287444 rset_bound: 0.37657937589518325
# log obj: 0.3764034333346042 rset_bound: 0.37657937589518325
# log obj: 0.376411686711461 rset_bound: 0.37657937589518325
# log obj: 0.37664393244063066 rset_bound: 0.37657937589518325
# log obj: 0.3766032023550524 rset_bound: 0.37657937589518325
# log obj: 0.3765622774266922 rset_bound: 0.37657937589518325
# log obj: 0.37659443349020283 rset_bound: 0.37657937589518325
# log obj: 0.376471514996252 rset_bound: 0.37657937589518325
# log obj: 0.3765077099866497 rset_bound: 0.37657937589518325
# log obj: 0.3761833433806898 rset_bound: 0.37657937589518325
# time: 0.9017782211303711
# SkinThickness
# ----------------------variable importance Minus----------------------
# Second solve time: 0.000976336
# log obj: 0.37544012824524914 rset_bound: 0.37657937589518325
# Second solve time: 0.001480049
# log obj: 0.3754420932476987 rset_bound: 0.37657937589518325
# ----------------------variable importance plus LP--------------------
# log obj: 0.37649074727016313 rset_bound: 0.37657937589518325
# log obj: 0.3764835899942101 rset_bound: 0.37657937589518325
# log obj: 0.37708809958309325 rset_bound: 0.37657937589518325
# /usr/project/xtmp/cz131/RsetGAM-camera-ready/src/rset_app.py:120: UserWarning: solution is out of the Rset.
#   warnings.warn("solution is out of the Rset. ")
# log obj: 0.3769516068804381 rset_bound: 0.37657937589518325
# time: 0.16846299171447754
# log obj: 0.376426690007985 rset_bound: 0.37657937589518325
# log obj: 0.37642876032323147 rset_bound: 0.37657937589518325
# log obj: 0.3777872237125022 rset_bound: 0.37657937589518325
# log obj: 0.3763872781284515 rset_bound: 0.37657937589518325
# time: 0.08680915832519531
# Insulin
# ----------------------variable importance Minus----------------------
# Second solve time: 0.001470398
# log obj: 0.3764494684832611 rset_bound: 0.37657937589518325
# Second solve time: 0.001772687
# log obj: 0.3765637643302356 rset_bound: 0.37657937589518325
# ----------------------variable importance plus LP--------------------
# log obj: 0.3763508628372192 rset_bound: 0.37657937589518325
# log obj: 0.37636727325594904 rset_bound: 0.37657937589518325
# log obj: 0.37642939935035 rset_bound: 0.37657937589518325
# log obj: 0.3763968048797741 rset_bound: 0.37657937589518325
# /usr/project/xtmp/cz131/RsetGAM-camera-ready/src/rset_app.py:353: UserWarning: solution is None
#   warnings.warn("solution is None")
# log obj: 0.37650174558608085 rset_bound: 0.37657937589518325
# log obj: 0.3764687224509015 rset_bound: 0.37657937589518325
# log obj: 0.3765234594123495 rset_bound: 0.37657937589518325
# log obj: 0.37646354898157103 rset_bound: 0.37657937589518325
# time: 0.6943264007568359
# log obj: 0.3766784505726847 rset_bound: 0.37657937589518325
# log obj: 0.37639647431270207 rset_bound: 0.37657937589518325
# log obj: 0.3764971660394244 rset_bound: 0.37657937589518325
# log obj: 0.3765809412061123 rset_bound: 0.37657937589518325
# log obj: 0.37669261078331495 rset_bound: 0.37657937589518325
# /usr/project/xtmp/cz131/RsetGAM-camera-ready/src/rset_app.py:120: UserWarning: solution is out of the Rset.
#   warnings.warn("solution is out of the Rset. ")
# log obj: 0.37656478287686124 rset_bound: 0.37657937589518325
# log obj: 0.37660831921396765 rset_bound: 0.37657937589518325
# log obj: 0.3766399600324718 rset_bound: 0.37657937589518325
# time: 0.35865235328674316
# BMI
# ----------------------variable importance Minus----------------------
# Second solve time: 0.001780093
# log obj: 0.3764284849921587 rset_bound: 0.37657937589518325
# Second solve time: 0.001387325
# log obj: 0.37670102426977764 rset_bound: 0.37657937589518325
# ----------------------variable importance plus LP--------------------
# /usr/project/xtmp/cz131/RsetGAM-camera-ready/src/rset_app.py:120: UserWarning: solution is out of the Rset.
#   warnings.warn("solution is out of the Rset. ")
# /usr/project/xtmp/cz131/RsetGAM-camera-ready/src/rset_app.py:353: UserWarning: solution is None
#   warnings.warn("solution is None")
# log obj: 0.37658258430672525 rset_bound: 0.37657937589518325
# log obj: 0.3765682431466653 rset_bound: 0.37657937589518325
# log obj: 0.3765593446623371 rset_bound: 0.37657937589518325
# log obj: 0.3765746965779178 rset_bound: 0.37657937589518325
# log obj: 0.3764967277732011 rset_bound: 0.37657937589518325
# log obj: 0.376489238213481 rset_bound: 0.37657937589518325
# log obj: 0.3765043603818128 rset_bound: 0.37657937589518325
# log obj: 0.3765205036286176 rset_bound: 0.37657937589518325
# time: 5.233961343765259
# log obj: 0.3769599905459273 rset_bound: 0.37657937589518325
# log obj: 0.376813990509971 rset_bound: 0.37657937589518325
# log obj: 0.3769233976921324 rset_bound: 0.37657937589518325
# log obj: 0.37681420353717776 rset_bound: 0.37657937589518325
# log obj: 0.3768295255105694 rset_bound: 0.37657937589518325
# log obj: 0.37658010533909086 rset_bound: 0.37657937589518325
# log obj: 0.37660507568043505 rset_bound: 0.37657937589518325
# log obj: 0.37658878107793703 rset_bound: 0.37657937589518325
# log obj: 0.37656007210902354 rset_bound: 0.37657937589518325
# log obj: 0.3766069492614011 rset_bound: 0.37657937589518325
# log obj: 0.37655676579498737 rset_bound: 0.37657937589518325
# log obj: 0.3765557686942089 rset_bound: 0.37657937589518325
# log obj: 0.37683093597236506 rset_bound: 0.37657937589518325
# log obj: 0.3768640332306354 rset_bound: 0.37657937589518325
# time: 2.8485939502716064
# DiabetesPedigreeFunction
# ----------------------variable importance Minus----------------------
# Second solve time: 0.001895049
# log obj: 0.37655814972150736 rset_bound: 0.37657937589518325
# Second solve time: 0.001491634
# log obj: 0.3766469382596308 rset_bound: 0.37657937589518325
# ----------------------variable importance plus LP--------------------
# /usr/project/xtmp/cz131/RsetGAM-camera-ready/src/rset_app.py:120: UserWarning: solution is out of the Rset.
#   warnings.warn("solution is out of the Rset. ")
# /usr/project/xtmp/cz131/RsetGAM-camera-ready/src/rset_app.py:353: UserWarning: solution is None
#   warnings.warn("solution is None")
# log obj: 0.3766774170635096 rset_bound: 0.37657937589518325
# log obj: 0.376760710199372 rset_bound: 0.37657937589518325
# log obj: 0.3764533809618581 rset_bound: 0.37657937589518325
# log obj: 0.3763949370956155 rset_bound: 0.37657937589518325
# time: 2.6357200145721436
# log obj: 0.3764633041410286 rset_bound: 0.37657937589518325
# log obj: 0.37662130489754186 rset_bound: 0.37657937589518325
# log obj: 0.37762371807364997 rset_bound: 0.37657937589518325
# log obj: 0.3776001924970496 rset_bound: 0.37657937589518325
# log obj: 0.37641525779407947 rset_bound: 0.37657937589518325
# log obj: 0.37649076055687497 rset_bound: 0.37657937589518325
# log obj: 0.37650787423857274 rset_bound: 0.37657937589518325
# log obj: 0.3763778842058336 rset_bound: 0.37657937589518325
# log obj: 0.3788786519658199 rset_bound: 0.37657937589518325
# log obj: 0.37715035255107593 rset_bound: 0.37657937589518325
# log obj: 0.37680277494166936 rset_bound: 0.37657937589518325
# time: 1.444946050643921
# Age
# ----------------------variable importance Minus----------------------
# Second solve time: 0.001785614
# log obj: 0.37650972451397835 rset_bound: 0.37657937589518325
# Second solve time: 0.001532143
# log obj: 0.37663806873184247 rset_bound: 0.37657937589518325
# ----------------------variable importance plus LP--------------------
# /usr/project/xtmp/cz131/RsetGAM-camera-ready/src/rset_app.py:120: UserWarning: solution is out of the Rset.
#   warnings.warn("solution is out of the Rset. ")
# /usr/project/xtmp/cz131/RsetGAM-camera-ready/src/rset_app.py:353: UserWarning: solution is None
#   warnings.warn("solution is None")
# log obj: 0.37657884214745013 rset_bound: 0.37657937589518325
# log obj: 0.3767441927901656 rset_bound: 0.37657937589518325
# time: 0.6705105304718018
# log obj: 0.3765931189526838 rset_bound: 0.37657937589518325
# log obj: 0.3766697259340765 rset_bound: 0.37657937589518325
# log obj: 0.3766221694102118 rset_bound: 0.37657937589518325
# log obj: 0.37661542259391434 rset_bound: 0.37657937589518325
# log obj: 0.37704293561386226 rset_bound: 0.37657937589518325
# log obj: 0.3765948121381772 rset_bound: 0.37657937589518325
# log obj: 0.3766005576912234 rset_bound: 0.37657937589518325
# time: 0.32500457763671875

# %% [markdown]
# ## Application 3: get monotonically increasing or decreasing shape function.
#
# Suppose we want to make ``BlooedPressure'' monotonically decreasing.

# %%
get_monotone(filepath, f="BloodPressure", direction="decrease")
# Out:
# feature BloodPressure
# ----------------------monotonicity----------------------
# Second solve time: 0.000394478
# log obj: 0.3765136014779818 rset_bound: 0.37657937589518325
# updated w [-1.18103902 -0.0570016   0.51656763  0.95098233 -1.89767234 -0.16963018
#   0.64125584  2.52703852  1.44436789  0.20119378  0.20119378 -0.21121714
#  -0.72977793  0.02812261 -2.25796162  0.12255898 -0.50450437 -7.56657066
#   2.29503095 -1.71026996 -0.46835083  0.06735156  0.68108175 -0.21267045
#   1.12692819  4.33967204 -0.82485941 -0.0387749   0.49286204  3.75524492
#  -3.82855895  2.55006791 -0.69361753  0.47578836  1.13627187 -1.10692616]

# %% [markdown]
# ## Application 4: get user preferred shape functions

# %%
w_user = np.array([ 1.55089258, 0.74716894,  0.74716894, -0.12313043, -0.65963492])
get_projection(filepath, f="BloodPressure", w_user=w_user)
# Out:
# feature BloodPressure
# ----------------------projection----------------------
# Second solve time: 0.001768389
# log obj: 0.376728416897528 rset_bound: 0.37657937589518325
# Second solve time: 0.002095133
# log obj: 0.3766790175332455 rset_bound: 0.37657937589518325
# w_fix [-1.13806888 -0.09460456  0.47839286  0.98775417 -1.97208434 -0.23773331
#   0.63338512  2.51487398  1.5498029   0.48711526  0.74534781 -0.12285662
#  -0.65981468  0.0272953  -2.36504238  0.09826116 -0.53466764 -7.98369308
#   2.47159251 -1.75653858 -0.48758746  0.10912645  0.65379258 -0.2631445
#   1.1084895   4.55958999 -0.87621442 -0.08466368  0.48294889  3.8096931
#  -3.97142533  2.68868138 -0.69359117  0.47979827  1.17242448 -1.06000037]
# w_not_fix [-1.16448979e+00 -1.23894451e-01  4.82261021e-01  9.88399338e-01
#  -1.97846152e+00 -2.45012966e-01  6.22627446e-01  2.51311007e+00
#   1.55944040e+00  5.88728301e-01  7.76311453e-01 -5.98233630e-02
#  -6.37494944e-01  7.64572891e-05 -2.36497755e+00  8.16543841e-02
#  -5.43055711e-01 -7.98312371e+00  2.47107321e+00 -1.76040587e+00
#  -4.93084381e-01  8.90628853e-02  6.48282789e-01 -2.59671115e-01
#   1.11614603e+00  4.55730209e+00 -8.78229059e-01 -8.91052176e-02
#   4.65549518e-01  3.80764413e+00 -3.97025635e+00  2.68827640e+00
#  -7.23655739e-01  4.77511835e-01  1.17772911e+00 -1.05950508e+00]
# /usr/project/xtmp/cz131/RsetGAM-camera-ready/src/rset_app.py:120: UserWarning: solution is out of the Rset.
#   warnings.warn("solution is out of the Rset. ")

# %% [markdown]
# ## Application 5: explore the changes in shape functions.
#
# There is a jump in the ``BloodPressure'' shape function around 60. We want to check if this pattern is also available in other models within the Rashomon set. We can sample models from the Rashomon set and calculate the frequency of the jump.

# %%
cnt = test_jump(filepath, n_samples=10000, i=9, j=10, k=11)
# Out:
# proportion: 1.0
